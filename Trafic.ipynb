# %%
import pandas as pd
df = pd.read_csv("Traffic-Prediction-using-Machine-Learning.csv")
df
# Out:
#             Day      Date  CodedDay  Zone  Weather  Temperature  Traffic
# 0     Wednesday  01-06-18         3     2       35           17        2
# 1     Wednesday  01-06-18         3     3       36           16        3
# 2     Wednesday  01-06-18         3     4       27           25        5
# 3     Wednesday  01-06-18         3     5       23           23        3
# 4     Wednesday  01-06-18         3     6       18           42        2
# ...         ...       ...       ...   ...      ...          ...      ...
# 1434     Friday  10-06-18         5   140       47           38        1
# 1435     Friday  10-06-18         5   141       15            8        4
# 1436     Friday  10-06-18         5   142       26           38        1
# 1437     Friday  10-06-18         5   143       16           34        3
# 1438     Friday  10-06-18         5   144       16           17        1
#
# [1439 rows x 7 columns]

# %% [markdown]
# ## 1. What kind of preprocessing was done to the dataset before trainning the model ##

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
le = LabelEncoder()
df['Day_Encoder'] = le.fit_transform(df['Day'])
print(df)
# Out:
#             Day      Date  CodedDay  Zone  Weather  Temperature  Traffic  \
# 0     Wednesday  01-06-18         3     2       35           17        2
# 1     Wednesday  01-06-18         3     3       36           16        3
# 2     Wednesday  01-06-18         3     4       27           25        5
# 3     Wednesday  01-06-18         3     5       23           23        3
# 4     Wednesday  01-06-18         3     6       18           42        2
# ...         ...       ...       ...   ...      ...          ...      ...
# 1434     Friday  10-06-18         5   140       47           38        1
# 1435     Friday  10-06-18         5   141       15            8        4
# 1436     Friday  10-06-18         5   142       26           38        1
# 1437     Friday  10-06-18         5   143       16           34        3
# 1438     Friday  10-06-18         5   144       16           17        1
#
#       Day_Encoder
# 0               6
# 1               6
# 2               6
# ...

# %%
df
# Out:
#             Day      Date  CodedDay  Zone  Weather  Temperature  Traffic  \
# 0     Wednesday  01-06-18         3     2       35           17        2
# 1     Wednesday  01-06-18         3     3       36           16        3
# 2     Wednesday  01-06-18         3     4       27           25        5
# 3     Wednesday  01-06-18         3     5       23           23        3
# 4     Wednesday  01-06-18         3     6       18           42        2
# ...         ...       ...       ...   ...      ...          ...      ...
# 1434     Friday  10-06-18         5   140       47           38        1
# 1435     Friday  10-06-18         5   141       15            8        4
# 1436     Friday  10-06-18         5   142       26           38        1
# 1437     Friday  10-06-18         5   143       16           34        3
# 1438     Friday  10-06-18         5   144       16           17        1
#
#       Day_Encoder
# 0               6
# 1               6
# 2               6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1439 entries, 0 to 1438
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          1439 non-null   object
#  1   Date         1439 non-null   object
#  2   CodedDay     1439 non-null   int64
#  3   Zone         1439 non-null   int64
#  4   Weather      1439 non-null   int64
#  5   Temperature  1439 non-null   int64
#  6   Traffic      1439 non-null   int64
#  7   Day_Encoder  1439 non-null   int32
# dtypes: int32(1), int64(5), object(2)
# memory usage: 84.4+ KB

# %%
Feature = df[['Weather','Temperature','CodedDay','Zone','Weather','Temperature','Day_Encoder']]
Feature
# Out:
#       Weather  Temperature  CodedDay  Zone  Weather  Temperature  Day_Encoder
# 0          35           17         3     2       35           17            6
# 1          36           16         3     3       36           16            6
# 2          27           25         3     4       27           25            6
# 3          23           23         3     5       23           23            6
# 4          18           42         3     6       18           42            6
# ...       ...          ...       ...   ...      ...          ...          ...
# 1434       47           38         5   140       47           38            0
# 1435       15            8         5   141       15            8            0
# 1436       26           38         5   142       26           38            0
# 1437       16           34         5   143       16           34            0
# 1438       16           17         5   144       16           17            0
#
# [1439 rows x 7 columns]

# %%
target=df[['Traffic']]
target
# Out:
#       Traffic
# 0           2
# 1           3
# 2           5
# 3           3
# 4           2
# ...       ...
# 1434        1
# 1435        4
# 1436        1
# 1437        3
# 1438        1
#
# [1439 rows x 1 columns]

# %% [markdown]
# ## 2. Which machinglearning algorithm was useed to predict traffic,and why was it chosen ##

# %%
print(df.isnull().sum())
# Out:
# Day            0
# Date           0
# CodedDay       0
# Zone           0
# Weather        0
# Temperature    0
# Traffic        0
# Day_Encoder    0
# dtype: int64

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Feature,target,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100)
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.21180555555555555

# %%
y_predicted = model.predict(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
dect = DecisionTreeClassifier()
dect.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dect.score(x_test,y_test)
# Out:
# 0.21875

# %% [markdown]
# ## 3. How were categorical variables(like Day and Zone)encoded for model input? ##

# %%
#Done before

# %% [markdown]
# ## 4.What metric was used to evaluate the model performance, and how is it calculated? ##

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(x_test)

# %%
accuracy= accuracy_score(y_test,y_pred)

# %%
print(f"Model Accuracy:{accuracy:.2f}")
# Out:
# Model Accuracy:0.21

# %%
error_rate=1 - accuracy
print("Error_rate:",error_rate)
# Out:
# Error_rate: 0.7881944444444444

# %%
import joblib

# %%
joblib.dump(model,"random_forest_model.pkl")
print("Model saved!")
# Out:
# Model saved!

# %% [markdown]
# ## 5.What does the calculated error rate of 12.16% indicate about the model performence? ##

# %%
# A lower error rate indicates a precise model but our error rate is about 78% so it is less precise model.

# %% [markdown]
# ## 6. How was the dataset split between trainning and testing? was cross-validation used? ##

# %%
# Yes I use the the like train_test_split.But cross_validation was not used.

# %% [markdown]
# ## 7.What are potential limitations or Improvements that can be made to increase model accuracy? ##

# %%
#Limitation
# The model might not capture complex patterns in the data .The data set may not account for all relevant feature(e.g.real time traffic events road condition)

# %%
# Improvement 
# Applying  hypermeter tuning and feature engineering can enhance performance.
# Implementing cross_validation would provide a more reliable evalution.
