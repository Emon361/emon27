# %%
import pandas as pd
df = pd.read_csv("Customer_Segmentation_py.csv")
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       26/11/2013   26  November  2013            19     Youth (<25)
# 1       26/11/2015   26  November  2015            19     Youth (<25)
# 2       23/03/2014   23     March  2014            49  Adults (35-64)
# 3       23/03/2016   23     March  2016            49  Adults (35-64)
# 4       15/05/2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  12/04/2016   12     April  2016            41  Adults (35-64)
# 113032  02/04/2014    2     April  2014            18     Youth (<25)
# 113033  02/04/2016    2     April  2016            18     Youth (<25)
# 113034  04/03/2014    4     March  2014            37  Adults (35-64)
# 113035  04/03/2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %% [markdown]
# ## 1.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
Age_Group_Counts = df['Age_Group'].value_counts().sort_index()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=Age_Group_Counts.index,y=Age_Group_Counts.values,palette = "viridis")
plt.title('Customer distribution across age groups')
plt.xlabel('Age_Group')
plt.ylabel('Number of Customers')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\3839479311.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Age_Group_Counts.index,y=Age_Group_Counts.values,palette = "viridis")

# %% [markdown]
# ## 2.

# %%
gender_country = df.groupby(['Country','Customer_Gender']).size().unstack()

# %%
plt.figure(figsize=(12,6))
gender_country.plot(kind='bar',stacked='True',colormap='coolwarm',figsize=(12,6))
plt.title('Customer Gender Distribution by Country')
plt.xlabel('Country')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.

# %%
category_quantity=df.groupby('Product_Category')['Order_Quantity'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=category_quantity.index,y=category_quantity.values,palette='crest')
plt.title('Total order quantity by product category')
plt.xlabel('Product_Category')
plt.ylabel('Total Order of Quantity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\3425608133.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_quantity.index,y=category_quantity.values,palette='crest')

# %%
subcategory_quantity=df.groupby('Sub_Category')['Order_Quantity'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=subcategory_quantity.index,y=subcategory_quantity.values,palette='crest')
plt.title('Total order quantity by sub category')
plt.xlabel('Sub_Category')
plt.ylabel('Total Order of Quantity')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\2020743919.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=subcategory_quantity.index,y=subcategory_quantity.values,palette='crest')

# %% [markdown]
# ## 4.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Features = df[['Order_Quantity','Profit','Revenue']]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(Features)

# %%
inertia=[]
for k in range(1,11):
    kmeans = KMeans(n_clusters=k,random_state=42)
    kmeans.fit(scaled_features)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,9))
plt.plot(range(1,11),inertia,marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
optimal_k = 4
kmeans = KMeans(n_clusters= optimal_k,random_state=42)
df['Cluster']=kmeans.fit_predict(scaled_features)

# %%
sns.pairplot(df[['Order_Quantity','Profit','Revenue','Cluster']],hue='Cluster',palette='Set2')
plt.suptitle('Customer Clusters based on Purchasing behavior',y=1.02)
plt.show()

# %% [markdown]
# ## 5.

# %%
cluster_summery = df.groupby('Cluster')[['Order_Quantity','Profit','Revenue']].mean()
print('Average purchasing behavior by clustering:')
print(cluster_summery)
# Out:
# Average purchasing behavior by clustering:
#          Order_Quantity       Profit      Revenue
# Cluster
# 0              3.288800   156.712052   480.622125
# 1              1.760811  1267.763683  3667.860938
# 2             14.183613   108.085128   222.410239
# 3             24.996953   229.514407   457.828610

# %%
demographics = df.groupby('Cluster')[['Customer_Age']].mean()
print('\nAverage age by cluster:')
print(demographics)
# Out:
# Average age by cluster:
#          Customer_Age
# Cluster
# 0           35.573880
# 1           35.644248
# 2           36.059500
# 3           36.335094

# %%
categorical_features = ['Customer_Gender','Age_Group','Product_Category']

# %%
for feature in categorical_features :
    print(f"\nDistribution of {feature} by Cluster:")
    print(df.groupby(['Cluster',feature]).size().unstack(fill_value=0))
# Out:
# Distribution of Customer_Gender by Cluster:
# Customer_Gender      F      M
# Cluster
# 0                18802  19896
# 1                 6328   6206
# 2                15499  16770
# 3                14095  15440
#
# Distribution of Age_Group by Cluster:
# Age_Group  Adults (35-64)  Seniors (64+)  Young Adults (25-34)  Youth (<25)
# Cluster
# 0                   18532            234                 13735         6197
# 1                    6335             23                  4524         1652
# 2                   16022            259                 10617         5371
# 3                   14935            214                  9778         4608
#
# Distribution of Product_Category by Cluster:
# Product_Category  Accessories  Bikes  Clothing
# Cluster
# 0                       20304  13545      4849
# 1                          95  12437         2
# 2                       26195      0      6074
# 3                       23526      0      6009

# %% [markdown]
# ## 6.

# %%
category_profit=df.groupby('Product_Category')[['Profit','Revenue']].sum().sort_values(by='Profit',ascending=False)

# %%
subcategory_profit=df.groupby('Sub_Category')[['Profit','Revenue']].sum().sort_values(by='Profit',ascending=False)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=category_profit.index,y=category_profit['Profit'],palette='magma')
plt.title('Total Profit by Product category')
plt.xlabel('Product_Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.figure(figsize=(10,5))
sns.barplot(x=category_profit.index,y=category_profit['Revenue'],palette='viridis')
plt.title('Total Revenue by Product category')
plt.xlabel('Product_Category')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.figure(figsize=(12,5))
sns.barplot(x=subcategory_profit.index,y=subcategory_profit['Profit'],palette='rocket')
plt.title('Total Profit by sub category')
plt.xlabel('Sub_Category')
plt.ylabel('Profit')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
plt.figure(figsize=(10,5))
sns.barplot(x=subcategory_profit.index,y=subcategory_profit['Revenue'],palette='coolwarm')
plt.title('Total Revenue by Sub category')
plt.xlabel('Sub_Category')
plt.ylabel('Revenue')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\1384302854.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_profit.index,y=category_profit['Profit'],palette='magma')
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\1384302854.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_profit.index,y=category_profit['Revenue'],palette='viridis')
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\1384302854.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## 7.

# %%
sns.pairplot(df[['Unit_Cost','Unit_Price','Profit']],kind='scatter',diag_kind='kde',plot_kws={'alpha':0.5})
plt.suptitle('Pairwise Relationships : Unit Cost , Unit Price, and Profit',y = 1.02)
plt.show()

# %%
correlation = df[['Unit_Cost','Unit_Price','Profit']].corr()
print('Correlation Matrix:\n',correlation)
# Out:
# Correlation Matrix:
#              Unit_Cost  Unit_Price   Profit
# Unit_Cost    1.000000    0.997894  0.74102
# Unit_Price   0.997894    1.000000  0.74987
# Profit       0.741020    0.749870  1.00000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Heatmap: Unit_Cost,Unit_Price,Profit')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8.

# %%
age_group_metrics=df.groupby('Age_Group')[['Revenue','Profit']].sum().sort_values(by='Revenue',ascending=False)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=age_group_metrics.index,y=age_group_metrics['Revenue'],palette='magma')
plt.title('Total Profit by Age Group')
plt.xlabel('Age_Group')
plt.ylabel('Revenue')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\262828336.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_metrics.index,y=age_group_metrics['Revenue'],palette='magma')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=age_group_metrics.index,y=age_group_metrics['Profit'],palette='viridis')
plt.title('Total Profit by Age Group')
plt.xlabel('Age_Group')
plt.ylabel('Profit')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\1958760468.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_metrics.index,y=age_group_metrics['Profit'],palette='viridis')

# %% [markdown]
# ## 9.

# %%
gender_revenue=df.groupby('Customer_Gender')['Revenue'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=gender_revenue.index,y=gender_revenue.values,palette='cool')
plt.title('Total Revenue by Customer Gender')
plt.xlabel('Customer_Gender')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\3991181290.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_revenue.index,y=gender_revenue.values,palette='cool')

# %%
print('Total Revenue by Gender:\n',gender_revenue)
# Out:
# Total Revenue by Gender:
#  Customer_Gender
# M    43335409
# F    41935599
# Name: Revenue, dtype: int64

# %% [markdown]
# ## 10.

# %%
df['Date']=pd.to_datetime(df['Date'],dayfirst=True)

# %%
df['YearMonth']=df['Date'].dt.to_period('M')

# %%
monthly_trends=df.groupby('YearMonth')[['Revenue','Profit']].sum()

# %%
plt.figure(figsize=(12,5))
monthly_trends['Revenue'].plot(marker='o',color='blue')
plt.title('Monthly Reveneu Trend')
plt.xlabel('YearMonth')
plt.ylabel('Revenue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
monthly_trends['Profit'].plot(marker='o',color='blue')
plt.title('Monthly Profit Trend')
plt.xlabel('YearMonth')
plt.ylabel('Profit')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
annual_trends = df.groupby('Year')[['Revenue','Profit']].sum()
print('Annual Trends:\n',annual_trends)
# Out:
# Annual Trends:
#         Revenue   Profit
# Year
# 2011   8964888  2881301
# 2012   9175983  2951993
# 2013  15240037  5959208
# 2014  14152724  5864087
# 2015  20023991  7528563
# 2016  17713385  7035948

# %% [markdown]
# ## 11.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
df['High_Order']=df['Order_Quantity']>=10

# %%
features =['Customer_Age','Customer_Gender','Age_Group','Product_Category','Sub_Category']
X=df[features]
Y=df['High_Order']

# %%
X_encoded =X.copy()
le = LabelEncoder()
for col in ['Customer_Age','Customer_Gender','Age_Group','Product_Category','Sub_Category']:
    X_encoded[col] = le.fit_transform(X[col])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_encoded,Y,test_size=0.3,random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=100,random_state=42)
clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
Y_pred = clf.predict(X_test)
print('Confusion Matrix:\n',confusion_matrix(Y_test,Y_pred))
print('\nClassification Report:\n',classification_report(Y_test,Y_pred))
# Out:
# Confusion Matrix:
#  [[ 8355  7812]
#  [  387 17357]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      0.52      0.67     16167
#         True       0.69      0.98      0.81     17744
#
#     accuracy                           0.76     33911
#    macro avg       0.82      0.75      0.74     33911
# weighted avg       0.82      0.76      0.74     33911

# %% [markdown]
# ## 12.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
features =['Customer_Age','Customer_Gender','Age_Group','Product_Category','Sub_Category','Unit_Cost','Unit_Price']
X=df[features]
Y=df['Profit']

# %%
X_encoded =X.copy()
le = LabelEncoder()
for col in ['Customer_Gender','Age_Group','Product_Category','Sub_Category']:
    X_encoded[col] = le.fit_transform(X[col])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_encoded,Y,test_size=0.3,random_state=42)

# %%
reg = RandomForestRegressor(n_estimators=100,random_state=42)
reg.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
Y_pred = reg.predict(X_test)
mse = mean_squared_error(Y_test,Y_pred)
r2=r2_score(Y_test,Y_pred)
print(f"Mean Squared Error : {mse:.2f}")
print(f"R^2 Score:{r2: .2f}")
# Out:
# Mean Squared Error : 70099.64
# R^2 Score: 0.66

# %% [markdown]
# ## 13.

# %%
country_counts = df['Country'].value_counts()

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=country_counts.index,y=country_counts.values,palette='pastel')
plt.title('Customer Distribution by Country')
plt.xlabel('Country')
plt.ylabel('Number of Records')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\2613407429.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index,y=country_counts.values,palette='pastel')

# %%
state_counts = df.groupby(['Country','State']).size().reset_index(name='Count')

# %%
plt.figure(figsize=(14,6))
sns.barplot(data = state_counts, x='State',y='Count',hue='Country',dodge = False)
plt.title('Customer Distribution by State (Grouped by Country)')
plt.xlabel('State')
plt.ylabel('Number of Records')
plt.xticks(rotation =90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 14.

# %%
category_summary = df.groupby('Product_Category')[['Revenue','Profit']].sum().sort_values(by='Revenue',ascending=False)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=category_summary.index,y=category_summary['Revenue'],palette='Blues')
plt.title('Total Revenue by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Revenue')
plt.xticks(rotation =45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\1829968076.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_summary.index,y=category_summary['Revenue'],palette='Blues')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=category_summary.index,y=category_summary['Revenue'],palette='Greens')
plt.title('Total Profit by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Profit')
plt.xticks(rotation =45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\1178497869.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_summary.index,y=category_summary['Revenue'],palette='Greens')

# %% [markdown]
# ## 15.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
features = df[['Order_Quantity','Profit','Revenue']]

# %%
sclaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
kmeans = KMeans(n_clusters = 4, random_state=42)
clusters = kmeans.fit_predict(scaled_features)

# %%
df['Cluster'] = clusters

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_features)
df['PCA1'] =pca_result[:,0]
df['PCA2'] = pca_result[:, 1]

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = df , x='PCA1',y='PCA2',hue='Cluster',palette='tab10',alpha=0.6)
plt.title('Customer Segments Based on Purchasing Behavior')
plt.xlabel('Principle Component 1')
plt.ylabel('Principle Component 2')
plt.legend(title='Cluster')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3592\2413438500.py:7: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
